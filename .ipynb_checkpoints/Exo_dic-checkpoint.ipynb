# %%
dic1A={'nom':"Joel",'présence':1}
dic2A={'nom':'Paterne','présence':0}
dic3A={'nom':'Roger','présence':1}
dic4A={'nom':'Marcel','présence':1}
dic5A={'nom':'Sandrine','présence':0}
dic6A={'nom':'Marc','présence':1}
dic7A={'nom':'Mathieu','présence':1}
dic8A={'nom':'Pascal','présence':0}
liste_écoA=[]
liste_écoA.append(dic1A)
liste_écoA.append(dic2A)
liste_écoA.append(dic3A)
liste_écoA.append(dic4A)
liste_écoA.append(dic5A)
liste_écoA.append(dic6A)
liste_écoA.append(dic7A)
liste_écoA.append(dic8A)

# %%
dic1B={'nom':"Joel",'présence':1}
dic2B={'nom':'Paterne','présence':0}
dic3B={'nom':'Roger','présence':0}
dic4B={'nom':'Marcel','présence':1}
dic5B={'nom':'Sandrine','présence':1}
dic6B={'nom':'Marc','présence':1}
dic7B={'nom':'Mathieu','présence':0}
dic8B={'nom':'Pascal','présence':1}
liste_écoB=[]
liste_écoB.append(dic1B)
liste_écoB.append(dic2B)
liste_écoB.append(dic3B)
liste_écoB.append(dic4B)
liste_écoB.append(dic5B)
liste_écoB.append(dic6B)
liste_écoB.append(dic7B)
liste_écoB.append(dic8B)
print(liste_écoA,liste_écoB)
# Out:
# [{'nom': 'Joel', 'présence': 1, 'sanction': 'Avertissement'}, {'nom': 'Paterne', 'présence': 0, 'sanction': 'Avertissement'}, {'nom': 'Roger', 'présence': 1, 'sanction': 'Avertissement'}, {'nom': 'Marcel', 'présence': 1, 'sanction': 'Avertissement'}, {'nom': 'Sandrine', 'présence': 0}, {'nom': 'Marc', 'présence': 1, 'sanction': 'Travaux forcé'}, {'nom': 'Mathieu', 'présence': 1, 'sanction': 'Travaux forcé'}, {'nom': 'Pascal', 'présence': 0}] [{'nom': 'Joel', 'présence': 1}, {'nom': 'Paterne', 'présence': 0}, {'nom': 'Roger', 'présence': 0}, {'nom': 'Marcel', 'présence': 1}, {'nom': 'Sandrine', 'présence': 1}, {'nom': 'Marc', 'présence': 1}, {'nom': 'Mathieu', 'présence': 0}, {'nom': 'Pascal', 'présence': 1}]

# %%
def attribuer_sanction():
    for i in liste_écoA:
        if i['nom']=='Sandrine' and i['présence']==1:
            i['sanction']= 'Travaux forcé'
            
        if i['nom']=='Marc' and i['présence']==1:
            i['sanction']= 'Travaux forcé'
            
        if i['nom']=='Pascal' and i['présence']==1:
            i['sanction']= 'Travaux forcé'
            
        if i['nom']=='Mathieu' and i['présence']==1:
            i['sanction']= 'Travaux forcé'
            
        if i['nom']=='Joel' and i['présence']==0:
            i['sanction']= 'Avertissement'
        elif i['nom']=='Joel' and i['présence']==1:
            i['sanction']= 'Pas de sanction'
            
        if i['nom']=='Paterne' and i['présence']==0:
            i['sanction']= 'Avertissement'
        elif ['nom']=='Paterne' and i['présence']==1:
            i['sanction']= 'Pas de sanction'
            
        if i['nom']=='Roger' and i['présence']==0:
            i['sanction']= 'Avertissement'
        elif i['nom']=='Roger' and i['présence']==1:
            i['sanction']= 'Pas de sanction'
            
        if i['nom']=='Marcel' and i['présence']==0:
            i['sanction']= 'Avertissement'
        elif i['nom']=='Marcel' and i['présence']==1:
            i['sanction']= 'Pas de sanction'
            
    for j in liste_écoB:
        if j['nom']=='Joel' and j['présence']==1:
            j['sanction']= 'Travaux forcé'
            
        if j['nom']=='Paterne' and j['présence']==1:
            j['sanction']= 'Travaux forcé'
            
        if j['nom']=='Roger' and j['présence']==1:
            j['sanction']= 'Travaux forcé'
            
        if j['nom']=='Marcel' and j['présence']==1:
            j['sanction']= 'Travaux forcé'
            
        if j['nom']=='Sandrine' and j['présence']==0:
            j['sanction']= 'Avertissement'
        elif j['nom']=='Sandrine' and j['présence']==1:
            j['sanction']= 'Pas de sanction'
            
        if j['nom']=='Marc' and j['présence']==0:
            j['sanction']= 'Avertissement'
        elif j['nom']=='Marc' and j['présence']==1:
            j['sanction']= 'Pas de sanction'
            
        if j['nom']=='Pascal' and j['présence']==0:
            j['sanction']= 'Avertissement'
        elif j['nom']=='Pascal' and j['présence']==1:
            j['sanction']= 'Pas de sanction'
            
        if j['nom']=='Mathieu' and j['présence']==0:
            j['sanction']= 'Avertissement'
        elif j['nom']=='Mathieu' and j['présence']==1:
            j['sanction']= 'Pas de sanction'
            
    
attribuer_sanction()
# Out:
# [{'nom': 'Joel', 'présence': 1, 'sanction': 'Travaux forcé'}, {'nom': 'Paterne', 'présence': 0, 'sanction': 'Pas de sanction'}, {'nom': 'Roger', 'présence': 0, 'sanction': 'Pas de sanction'}, {'nom': 'Marcel', 'présence': 1, 'sanction': 'Travaux forcé'}, {'nom': 'Sandrine', 'présence': 1, 'sanction': 'Pas de sanction'}, {'nom': 'Marc', 'présence': 1, 'sanction': 'Pas de sanction'}, {'nom': 'Mathieu', 'présence': 0, 'sanction': 'Avertissement'}, {'nom': 'Pascal', 'présence': 1, 'sanction': 'Pas de sanction'}]

# %%
listA=['Joel','Paterne','Roger','Marcel']
listB=['Sandrine','Marc','Pascal','Mathieu']
def sanction():
    liste_sanctions=[]
    for i in listA:
        for j in liste_écoA:
            if i==j['nom'] and j['présence']==0:
                dico={'nom':i, 'sanction1':'Avertissement'}
            elif i==j['nom'] and j['présence']==1:
                dico={'nom':i, 'sanction1':'Pas de sanction'}
        for k in liste_écoB:
            if i==k['nom'] and k['présence']==1:
                dico['sanction2']='Travaux forcés'
            elif i==k['nom'] and k['présence']==0:
                dico['sanction2']='Pas de sanction'
        liste_sanctions.append(dico)
   
    for i in listB:
        for j in liste_écoA:
            if i==j['nom'] and j['présence']==0:
                dico1={'nom':i, 'sanction1':'Pas de sanction'}
            elif i==j['nom'] and j['présence']==1:
                dico1={'nom':i, 'sanction1':'Travaux forcés'}
        for k in liste_écoB:
            if i==k['nom'] and k['présence']==1:
                dico1['sanction2']='Pas de sanction'
            elif i==k['nom'] and k['présence']==0:
                dico1['sanction2']='Avertissement'
        liste_sanctions.append(dico1)
    #print(liste_sanctions)
    
    liste=[]
    for k in liste_sanctions:
        if k['sanction1']=='Pas de sanction' and k['sanction2']=='Pas de sanction':
            dic={'nom':k['nom'], 'sanction':''}
        elif k['sanction2']=='Avertissement':
            dic={'nom':k['nom'], 'sanction':'Avertissement'}
        elif k['sanction2']=='Travaux forcés':
            dic={'nom':k['nom'], 'sanction':'Travaux forcés'}
            
        if k['sanction1']=='Avertissement' and k['sanction2']=='Pas de sanction':
            dic={'nom':k['nom'], 'sanction':'Avertissement'}
        elif k['sanction2']=='Avertissement':
            dic={'nom':k['nom'], 'sanction':'Avertissement'}
        elif k['sanction2']=='Travaux forcés':
            dic={'nom':k['nom'], 'sanction':'Travaux forcés'}
        
        if k['sanction1']=='Travaux forcés' and k['sanction2']=='Pas de sanction':
            dic={'nom':k['nom'], 'sanction':'Renvoie'}
        elif k['sanction2']=='Avertissement':
            dic={'nom':k['nom'], 'sanction':'Travaux forcés'}
        elif k['sanction2']=='Travaux forcés':
            dic={'nom':k['nom'], 'sanction':'Renvoie'}
        liste.append(dic)
    for e in liste:
        if e['sanction']!='Pas de sanction':
            print(e['nom'],'|',e['sanction'])
    
sanction()
# Out:
# Joel | Renvoie
# Paterne | Avertissement
# Roger |
# Marcel | Renvoie
# Sandrine |
# Marc | Renvoie
# Pascal |
# Mathieu | Travaux forcés
